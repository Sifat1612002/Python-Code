# %%
#Importing the sympy library
#import matplotlib as mpl
#import matplotlib.pyplot as plt
#import numpy as np
import sympy as sp
from sympy import *
from sympy.plotting import plot
init_printing(pretty_print=True)
# Defining mathematical function by using sp.symbols()
x,y,z=sp.symbols('x y z')
expr1= sp.sin(x)
# This is to check out the graph of the mathematical function
sp.plot(expr1, show=True)
# Differentiating the given function
diff1=sp.diff(expr1,x)
#Equating the derivative function to 0 and obtaining the value at which minima and maxima occurs
check1=sp.solve(diff1,x)
# Differentiating the function one more to determine at what value of x do the maxima and minima occurs
diff2=sp.diff(diff1,x)
# Evaluating and storing exactly at what values of x do the maxima and minima occurs
maxmin1=diff2.subs(x,check1[0])
maxmin2=diff2.subs(x,check1[1])
if maxmin1<0:
    max=expr1.subs(x,check1[0])
    min=expr1.subs(x,check1[1])
elif maxmin>0:
    min=expr1.subs(x,check1[0])
    max=expr1.subs(x,check1[1])
    
print("Maximum value is", max, "and minimum value is", min)
# Out:
# Maximum value is 1 and minimum value is -1

# %%
diff1
# Out:
# cos(x)

# %%
check1
# Out:
# ⎡π  3⋅π⎤
# ⎢─, ───⎥
# ⎣2   2 ⎦

# %%
diff2
# Out:
# -sin(x)

# %%
maxmin1
# Out:
# -1

# %%
maxmin2
# Out:
# 1
